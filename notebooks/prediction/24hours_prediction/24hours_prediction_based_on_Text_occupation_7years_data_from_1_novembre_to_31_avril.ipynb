# %%
import sys
import os
import importlib

# Ajout du chemin une fois
sys.path.append(os.path.abspath('../../../python_files'))

# Liste des noms des modules à importer et recharger
module_names = [
    'preprocessing',
    'imports',
    'files',
    'clustering',
    'profile_prediction',
    'prediction_24h'
]

# Import et reload automatique
modules = {}
for name in module_names:
    modules[name] = importlib.import_module(name)
    importlib.reload(modules[name])

# Importer tout en global namespace (équivalent à from ... import *)
for name in module_names:
    exec(f'from {name} import *')

# %%
Simulation_Dataset = {
    "2018": "../../../data/simulated_data_7years/Mal_isole/2018/Simulation_Outputs",
    "2019": "../../../data/simulated_data_7years/Mal_isole/2019/Simulation_Outputs",
    "2020": "../../../data/simulated_data_7years/Mal_isole/2020/Simulation_Outputs",
    "2021": "../../../data/simulated_data_7years/Mal_isole/2021/Simulation_Outputs",
    "2022": "../../../data/simulated_data_7years/Mal_isole/2022/Simulation_Outputs",
    "2023": "../../../data/simulated_data_7years/Mal_isole/2023/Simulation_Outputs",
    "2024": "../../../data/simulated_data_7years/Mal_isole/2024/Simulation_Outputs"   
}

Weather_Dataset = {
    "2018": "../../../data/simulated_data_7years/Mal_isole/2018/Weather_Dataset.txt",
    "2019": "../../../data/simulated_data_7years/Mal_isole/2019/Weather_Dataset.txt",
    "2020": "../../../data/simulated_data_7years/Mal_isole/2020/Weather_Dataset.txt",
    "2021": "../../../data/simulated_data_7years/Mal_isole/2021/Weather_Dataset.txt",
    "2022": "../../../data/simulated_data_7years/Mal_isole/2022/Weather_Dataset.txt",
    "2023": "../../../data/simulated_data_7years/Mal_isole/2023/Weather_Dataset.txt",
    "2024": "../../../data/simulated_data_7years/Mal_isole/2024/Weather_Dataset.txt"   
}

# %%
consommation_chauffage = extract_and_concat_consommation(Simulation_Dataset, column_index=4, prefix="consommation_heat_")

# Exemple d'utilisation
city_groups = {
    "Weather_Dataset": Weather_Dataset
   
    
}

prefix_column_map = {
    "Text_": 1,
    "Hum_": 3,
    "Wind_": 4,
    "Solar_": 5,
    "Ground_": 10
}

combined_data = extract_and_combine_all(city_groups, prefix_column_map)

Text_combined = combined_data.get('Text_combined_Weather_Dataset')
occupation=pd.read_csv("../../../data/simulated_data_7years/Mal_isole/Occup_Schedule_Youssef.txt")
occ_df = pd.DataFrame(occupation["Occupancy"].values[:8760].reshape(-1, 24))
occupation_7years = pd.concat([occ_df] * 7, ignore_index=True)

# %%
Text_Occ_heat_profil_7years=pd.read_csv("../../../data/simulated_data_7years/result_data/profile_prediction_Text_Occupation_7years_data_from_1_novembre_to_31_avril.csv")

# %%
start_date = "2018-01-01"
dates = pd.date_range(start=start_date, periods=len(consommation_chauffage), freq="D") 
consommation_chauffage.insert(0, "Date", dates)

add_heating_season(consommation_chauffage)

df_conso = consommation_chauffage[consommation_chauffage["heat"] == 1].copy().reset_index(drop=True)

# %%
df2=pd.concat([Text_Occ_heat_profil_7years.iloc[:, :],df_conso.iloc[:, 1:-1]],axis=1).reset_index(drop=True)

# %%
df2['Date'] = pd.to_datetime(df2['Date'])

df2 = df2.sort_values('Date').reset_index(drop=True)

combined_rows = []

for idx, row in df2.iterrows():
    jour = row['Date']
    jour_precedent = jour - pd.Timedelta(days=1)

    prev_row = df2[df2['Date'] == jour_precedent]

    if not prev_row.empty:
        prev_row = prev_row.iloc[0]
        prev_row_renamed = prev_row.add_suffix('_j-1')
        #prev_row_renamed = prev_row_renamed.drop(['Date', 'Date_j-1'], errors='ignore')

        # Inverser l'ordre ici
        combined_row = pd.concat([prev_row_renamed.to_frame().T.reset_index(drop=True), 
                                  row.to_frame().T.reset_index(drop=True)], axis=1)

        combined_rows.append(combined_row)
    else:
        continue

df_final = pd.concat(combined_rows, ignore_index=True)
cols_to_drop = [col for col in df_final.columns if isinstance(col, str) and 'Date' in col]
df_final = df_final.drop(columns=cols_to_drop)

# %%
y2= df_final.iloc[:, -24:].values 
X2 = df_final.iloc[:, :-24].values 

scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X2 = scaler_X.fit_transform(X2)
y2 = scaler_y.fit_transform(y2)

X2 = X2.reshape(X2.shape[0], 1, X2.shape[1])

X_train2, X_test2, y_train2, y_test2 = train_test_split(
    X2, y2, test_size=0.2, shuffle=False
)


# Vérification des dimensions
print("Shape de X_train2 :", X_train2.shape)
print("Shape de X_test2 :", X_test2.shape)
print("Shape de y_train2 :", y_train2.shape)
print("Shape de y_test2 :", y_test2.shape)
# Out:
# Shape de X_train2 : (1007, 1, 124)
# Shape de X_test2 : (252, 1, 124)
# Shape de y_train2 : (1007, 24)
# Shape de y_test2 : (252, 24)

# %%
model2, history2, loss2, mae2, mse2, rmse2, mae_test2, mse_test2, rmse_test2, r2, cvrmse, predictions2 = model_lstm(
    X_train2, 
    y_train2, 
    X_test2, 
    y_test2, 
    scaler_X, 
    scaler_y
)
# Out:
# c:\Users\toubia\anaconda3\envs\notebook\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0686 - mae: 0.1903 - mse: 0.0686 - val_loss: 0.0435 - val_mae: 0.1442 - val_mse: 0.0435
# Epoch 2/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0310 - mae: 0.1259 - mse: 0.0310 - val_loss: 0.0211 - val_mae: 0.1010 - val_mse: 0.0211
# Epoch 3/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0199 - mae: 0.1025 - mse: 0.0199 - val_loss: 0.0164 - val_mae: 0.0901 - val_mse: 0.0164
# Epoch 4/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0142 - mae: 0.0865 - mse: 0.0142 - val_loss: 0.0144 - val_mae: 0.0831 - val_mse: 0.0144
# Epoch 5/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0151 - mae: 0.0882 - mse: 0.0151 - val_loss: 0.0130 - val_mae: 0.0803 - val_mse: 0.0130
# Epoch 6/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0130 - mae: 0.0820 - mse: 0.0130 - val_loss: 0.0120 - val_mae: 0.0750 - val_mse: 0.0120
# Epoch 7/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0132 - mae: 0.0812 - mse: 0.0132 - val_loss: 0.0111 - val_mae: 0.0715 - val_mse: 0.0111
# Epoch 8/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0111 - mae: 0.0750 - mse: 0.0111 - val_loss: 0.0105 - val_mae: 0.0694 - val_mse: 0.0105
# Epoch 9/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0111 - mae: 0.0740 - mse: 0.0111 - val_loss: 0.0098 - val_mae: 0.0669 - val_mse: 0.0098
# Epoch 10/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0099 - mae: 0.0711 - mse: 0.0099 - val_loss: 0.0094 - val_mae: 0.0650 - val_mse: 0.0094
# Epoch 11/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0096 - mae: 0.0690 - mse: 0.0096 - val_loss: 0.0089 - val_mae: 0.0636 - val_mse: 0.0089
# Epoch 12/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0093 - mae: 0.0692 - mse: 0.0093 - val_loss: 0.0085 - val_mae: 0.0617 - val_mse: 0.0085
# Epoch 13/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0085 - mae: 0.0652 - mse: 0.0085 - val_loss: 0.0085 - val_mae: 0.0618 - val_mse: 0.0085
# Epoch 14/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0090 - mae: 0.0664 - mse: 0.0090 - val_loss: 0.0081 - val_mae: 0.0608 - val_mse: 0.0081
# Epoch 15/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0087 - mae: 0.0655 - mse: 0.0087 - val_loss: 0.0075 - val_mae: 0.0583 - val_mse: 0.0075
# Epoch 16/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0078 - mae: 0.0616 - mse: 0.0078 - val_loss: 0.0077 - val_mae: 0.0581 - val_mse: 0.0077
# Epoch 17/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0079 - mae: 0.0610 - mse: 0.0079 - val_loss: 0.0073 - val_mae: 0.0566 - val_mse: 0.0073
# Epoch 18/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0078 - mae: 0.0609 - mse: 0.0078 - val_loss: 0.0071 - val_mae: 0.0564 - val_mse: 0.0071
# Epoch 19/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0077 - mae: 0.0605 - mse: 0.0077 - val_loss: 0.0069 - val_mae: 0.0558 - val_mse: 0.0069
# Epoch 20/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0070 - mae: 0.0583 - mse: 0.0070 - val_loss: 0.0070 - val_mae: 0.0559 - val_mse: 0.0070
# Epoch 21/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0077 - mae: 0.0592 - mse: 0.0077 - val_loss: 0.0066 - val_mae: 0.0537 - val_mse: 0.0066
# Epoch 22/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0079 - mae: 0.0619 - mse: 0.0079 - val_loss: 0.0064 - val_mae: 0.0536 - val_mse: 0.0064
# Epoch 23/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0073 - mae: 0.0584 - mse: 0.0073 - val_loss: 0.0066 - val_mae: 0.0552 - val_mse: 0.0066
# Epoch 24/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0074 - mae: 0.0588 - mse: 0.0074 - val_loss: 0.0065 - val_mae: 0.0519 - val_mse: 0.0065
# Epoch 25/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0067 - mae: 0.0565 - mse: 0.0067 - val_loss: 0.0061 - val_mae: 0.0513 - val_mse: 0.0061
# Epoch 26/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0065 - mae: 0.0549 - mse: 0.0065 - val_loss: 0.0067 - val_mae: 0.0542 - val_mse: 0.0067
# Epoch 27/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0065 - mae: 0.0556 - mse: 0.0065 - val_loss: 0.0059 - val_mae: 0.0512 - val_mse: 0.0059
# Epoch 28/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0072 - mae: 0.0575 - mse: 0.0072 - val_loss: 0.0067 - val_mae: 0.0542 - val_mse: 0.0067
# Epoch 29/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0068 - mae: 0.0569 - mse: 0.0068 - val_loss: 0.0059 - val_mae: 0.0514 - val_mse: 0.0059
# Epoch 30/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0067 - mae: 0.0545 - mse: 0.0067 - val_loss: 0.0058 - val_mae: 0.0504 - val_mse: 0.0058
# Epoch 31/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0066 - mae: 0.0553 - mse: 0.0066 - val_loss: 0.0062 - val_mae: 0.0511 - val_mse: 0.0062
# Epoch 32/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0066 - mae: 0.0550 - mse: 0.0066 - val_loss: 0.0059 - val_mae: 0.0512 - val_mse: 0.0059
# Epoch 33/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0063 - mae: 0.0543 - mse: 0.0063 - val_loss: 0.0059 - val_mae: 0.0513 - val_mse: 0.0059
# Epoch 34/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0062 - mae: 0.0537 - mse: 0.0062 - val_loss: 0.0058 - val_mae: 0.0513 - val_mse: 0.0058
# Epoch 35/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0068 - mae: 0.0561 - mse: 0.0068 - val_loss: 0.0057 - val_mae: 0.0499 - val_mse: 0.0057
# Epoch 36/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0067 - mae: 0.0554 - mse: 0.0067 - val_loss: 0.0057 - val_mae: 0.0491 - val_mse: 0.0057
# Epoch 37/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0062 - mae: 0.0532 - mse: 0.0062 - val_loss: 0.0060 - val_mae: 0.0501 - val_mse: 0.0060
# Epoch 38/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0065 - mae: 0.0535 - mse: 0.0065 - val_loss: 0.0055 - val_mae: 0.0487 - val_mse: 0.0055
# Epoch 39/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0060 - mae: 0.0525 - mse: 0.0060 - val_loss: 0.0063 - val_mae: 0.0514 - val_mse: 0.0063
# Epoch 40/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0065 - mae: 0.0551 - mse: 0.0065 - val_loss: 0.0056 - val_mae: 0.0490 - val_mse: 0.0056
# Epoch 41/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0061 - mae: 0.0529 - mse: 0.0061 - val_loss: 0.0054 - val_mae: 0.0486 - val_mse: 0.0054
# Epoch 42/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0063 - mae: 0.0534 - mse: 0.0063 - val_loss: 0.0066 - val_mae: 0.0523 - val_mse: 0.0066
# Epoch 43/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0057 - mae: 0.0504 - mse: 0.0057 - val_loss: 0.0057 - val_mae: 0.0497 - val_mse: 0.0057
# Epoch 44/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0060 - mae: 0.0520 - mse: 0.0060 - val_loss: 0.0053 - val_mae: 0.0465 - val_mse: 0.0053
# Epoch 45/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0059 - mae: 0.0512 - mse: 0.0059 - val_loss: 0.0053 - val_mae: 0.0466 - val_mse: 0.0053
# Epoch 46/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0052 - mae: 0.0487 - mse: 0.0052 - val_loss: 0.0050 - val_mae: 0.0456 - val_mse: 0.0050
# Epoch 47/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0061 - mae: 0.0518 - mse: 0.0061 - val_loss: 0.0054 - val_mae: 0.0486 - val_mse: 0.0054
# Epoch 48/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0052 - mae: 0.0484 - mse: 0.0052 - val_loss: 0.0053 - val_mae: 0.0468 - val_mse: 0.0053
# Epoch 49/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0053 - mae: 0.0494 - mse: 0.0053 - val_loss: 0.0049 - val_mae: 0.0452 - val_mse: 0.0049
# Epoch 50/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0054 - mae: 0.0503 - mse: 0.0054 - val_loss: 0.0053 - val_mae: 0.0482 - val_mse: 0.0053
# Epoch 51/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0057 - mae: 0.0507 - mse: 0.0057 - val_loss: 0.0051 - val_mae: 0.0463 - val_mse: 0.0051
# Epoch 52/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0053 - mae: 0.0490 - mse: 0.0053 - val_loss: 0.0048 - val_mae: 0.0450 - val_mse: 0.0048
# Epoch 53/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0056 - mae: 0.0496 - mse: 0.0056 - val_loss: 0.0049 - val_mae: 0.0450 - val_mse: 0.0049
# Epoch 54/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0059 - mae: 0.0518 - mse: 0.0059 - val_loss: 0.0053 - val_mae: 0.0488 - val_mse: 0.0053
# Epoch 55/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0057 - mae: 0.0506 - mse: 0.0057 - val_loss: 0.0047 - val_mae: 0.0437 - val_mse: 0.0047
# Epoch 56/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0055 - mae: 0.0498 - mse: 0.0055 - val_loss: 0.0052 - val_mae: 0.0459 - val_mse: 0.0052
# Epoch 57/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - mae: 0.0475 - mse: 0.0051 - val_loss: 0.0052 - val_mae: 0.0459 - val_mse: 0.0052
# Epoch 58/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0052 - mae: 0.0479 - mse: 0.0052 - val_loss: 0.0049 - val_mae: 0.0460 - val_mse: 0.0049
# Epoch 59/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0053 - mae: 0.0494 - mse: 0.0053 - val_loss: 0.0049 - val_mae: 0.0445 - val_mse: 0.0049
# Epoch 60/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0054 - mae: 0.0499 - mse: 0.0054 - val_loss: 0.0048 - val_mae: 0.0436 - val_mse: 0.0048
# Epoch 61/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0051 - mae: 0.0486 - mse: 0.0051 - val_loss: 0.0048 - val_mae: 0.0443 - val_mse: 0.0048
# Epoch 62/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0055 - mae: 0.0497 - mse: 0.0055 - val_loss: 0.0047 - val_mae: 0.0435 - val_mse: 0.0047
# Epoch 63/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - mae: 0.0479 - mse: 0.0051 - val_loss: 0.0046 - val_mae: 0.0426 - val_mse: 0.0046
# Epoch 64/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0050 - mae: 0.0472 - mse: 0.0050 - val_loss: 0.0047 - val_mae: 0.0449 - val_mse: 0.0047
# Epoch 65/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0056 - mae: 0.0504 - mse: 0.0056 - val_loss: 0.0047 - val_mae: 0.0428 - val_mse: 0.0047
# Epoch 66/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0049 - mae: 0.0474 - mse: 0.0049 - val_loss: 0.0052 - val_mae: 0.0467 - val_mse: 0.0052
# Epoch 67/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - mae: 0.0471 - mse: 0.0051 - val_loss: 0.0048 - val_mae: 0.0430 - val_mse: 0.0048
# Epoch 68/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - mae: 0.0461 - mse: 0.0047 - val_loss: 0.0053 - val_mae: 0.0466 - val_mse: 0.0053
# Epoch 69/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0052 - mae: 0.0478 - mse: 0.0052 - val_loss: 0.0051 - val_mae: 0.0456 - val_mse: 0.0051
# Epoch 70/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0052 - mae: 0.0483 - mse: 0.0052 - val_loss: 0.0046 - val_mae: 0.0429 - val_mse: 0.0046
# Epoch 71/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - mae: 0.0477 - mse: 0.0051 - val_loss: 0.0047 - val_mae: 0.0437 - val_mse: 0.0047
# Epoch 72/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0047 - mae: 0.0460 - mse: 0.0047 - val_loss: 0.0052 - val_mae: 0.0467 - val_mse: 0.0052
# Epoch 73/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0055 - mae: 0.0497 - mse: 0.0055 - val_loss: 0.0046 - val_mae: 0.0437 - val_mse: 0.0046
# Epoch 74/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0054 - mae: 0.0482 - mse: 0.0054 - val_loss: 0.0045 - val_mae: 0.0419 - val_mse: 0.0045
# Epoch 75/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0055 - mae: 0.0495 - mse: 0.0055 - val_loss: 0.0047 - val_mae: 0.0424 - val_mse: 0.0047
# Epoch 76/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0052 - mae: 0.0477 - mse: 0.0052 - val_loss: 0.0044 - val_mae: 0.0417 - val_mse: 0.0044
# Epoch 77/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0046 - mae: 0.0458 - mse: 0.0046 - val_loss: 0.0046 - val_mae: 0.0432 - val_mse: 0.0046
# Epoch 78/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0048 - mae: 0.0458 - mse: 0.0048 - val_loss: 0.0046 - val_mae: 0.0426 - val_mse: 0.0046
# Epoch 79/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0050 - mae: 0.0469 - mse: 0.0050 - val_loss: 0.0047 - val_mae: 0.0430 - val_mse: 0.0047
# Epoch 80/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0052 - mae: 0.0473 - mse: 0.0052 - val_loss: 0.0049 - val_mae: 0.0439 - val_mse: 0.0049
# Epoch 81/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0054 - mae: 0.0483 - mse: 0.0054 - val_loss: 0.0046 - val_mae: 0.0422 - val_mse: 0.0046
# Epoch 82/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0050 - mae: 0.0468 - mse: 0.0050 - val_loss: 0.0044 - val_mae: 0.0418 - val_mse: 0.0044
# Epoch 83/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - mae: 0.0470 - mse: 0.0051 - val_loss: 0.0044 - val_mae: 0.0419 - val_mse: 0.0044
# Epoch 84/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - mae: 0.0449 - mse: 0.0045 - val_loss: 0.0041 - val_mae: 0.0399 - val_mse: 0.0041
# Epoch 85/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0049 - mae: 0.0461 - mse: 0.0049 - val_loss: 0.0046 - val_mae: 0.0419 - val_mse: 0.0046
# Epoch 86/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0044 - mae: 0.0433 - mse: 0.0044 - val_loss: 0.0046 - val_mae: 0.0421 - val_mse: 0.0046
# Epoch 87/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0050 - mae: 0.0466 - mse: 0.0050 - val_loss: 0.0044 - val_mae: 0.0420 - val_mse: 0.0044
# Epoch 88/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0048 - mae: 0.0465 - mse: 0.0048 - val_loss: 0.0046 - val_mae: 0.0421 - val_mse: 0.0046
# Epoch 89/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0048 - mae: 0.0457 - mse: 0.0048 - val_loss: 0.0043 - val_mae: 0.0409 - val_mse: 0.0043
# Epoch 90/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0053 - mae: 0.0481 - mse: 0.0053 - val_loss: 0.0046 - val_mae: 0.0417 - val_mse: 0.0046
# Epoch 91/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0048 - mae: 0.0462 - mse: 0.0048 - val_loss: 0.0044 - val_mae: 0.0419 - val_mse: 0.0044
# Epoch 92/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0052 - mae: 0.0470 - mse: 0.0052 - val_loss: 0.0044 - val_mae: 0.0423 - val_mse: 0.0044
# Epoch 93/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0048 - mae: 0.0458 - mse: 0.0048 - val_loss: 0.0044 - val_mae: 0.0402 - val_mse: 0.0044
# Epoch 94/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0048 - mae: 0.0453 - mse: 0.0048 - val_loss: 0.0044 - val_mae: 0.0413 - val_mse: 0.0044
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0054 - mae: 0.0465 - mse: 0.0054
# Validation Loss : 0.004142381250858307
# Validation MAE: 0.03992626816034317
# Validation MSE: 0.004142381250858307
# Validation RMSE: 0.06436133350745855
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Test MAE: 291.2615411841936
# Test MSE: 223428.164155842
# Test RMSE: 472.68188473416456
# Test R²: 0.8478471214217601
# Test CVRMSE: 0.4321774869336795
